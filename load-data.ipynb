# %%
library(tidyverse)
library(tidymodels)

data_url <- "https://archive.ics.uci.edu/ml/machine-learning-databases/undocumented/connectionist-bench/sonar/sonar.all-data"
# Out:
# Warning message:
# “package ‘tidymodels’ was built under R version 4.0.2”
# ── Attaching packages ────────────────────────────────────── tidymodels 0.1.1 ──
#
# ✔ broom     0.7.0      ✔ recipes   0.1.13
# ✔ dials     0.0.9      ✔ rsample   0.0.7
# ✔ infer     0.5.4      ✔ tune      0.1.1
# ✔ modeldata 0.0.2      ✔ workflows 0.2.0
# ✔ parsnip   0.1.3      ✔ yardstick 0.0.7
#
# Warning message:
# “package ‘broom’ was built under R version 4.0.2”
# Warning message:
# “package ‘dials’ was built under R version 4.0.2”
# Warning message:
# “package ‘infer’ was built under R version 4.0.3”
# Warning message:
# “package ‘modeldata’ was built under R version 4.0.1”
# Warning message:
# “package ‘parsnip’ was built under R version 4.0.2”
# Warning message:
# “package ‘recipes’ was built under R version 4.0.1”
# Warning message:
# “package ‘tune’ was built under R version 4.0.2”
# Warning message:
# “package ‘workflows’ was built under R version 4.0.2”
# Warning message:
# “package ‘yardstick’ was built under R version 4.0.2”
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()

# %%
data <- read_delim(data_url, delim = ",",
                  col_names=c('FB_1', 'FB_2', 'FB_3', 'FB_4', 'FB_5', 'FB_6', 'FB_7', 'FB_8', 'FB_9', 'FB_10', 'FB_11', 'FB_12', 'FB_13',
            'FB_14', 'FB_15', 'FB_16', 'FB_17', 'FB_18', 'FB_19', 'FB_20', 'FB_21', 'FB_22', 'FB_23', 'FB_24', 'FB_25', 'FB_26',
            'FB_27', 'FB_28', 'FB_29', 'FB_30', 'FB_31', 'FB_32', 'FB_33', 'FB_34', 'FB_35', 'FB_36', 'FB_37', 'FB_38', 'FB_39',
            'FB_40', 'FB_41', 'FB_42', 'FB_43', 'FB_44', 'FB_45', 'FB_46', 'FB_47', 'FB_48', 'FB_49', 'FB_50', 'FB_51', 'FB_52',
            'FB_53', 'FB_54', 'FB_55', 'FB_56', 'FB_57', 'FB_58', 'FB_59', 'FB_60', 'classification')) # FB -> Frequency Band

data
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   classification = col_character()
# )
#
# See spec(...) for full column specifications.
#     FB_1   FB_2   FB_3   FB_4   FB_5   FB_6   FB_7   FB_8   FB_9   FB_10  ⋯
# 1   0.0200 0.0371 0.0428 0.0207 0.0954 0.0986 0.1539 0.1601 0.3109 0.2111 ⋯
# 2   0.0453 0.0523 0.0843 0.0689 0.1183 0.2583 0.2156 0.3481 0.3337 0.2872 ⋯
# 3   0.0262 0.0582 0.1099 0.1083 0.0974 0.2280 0.2431 0.3771 0.5598 0.6194 ⋯
# 4   0.0100 0.0171 0.0623 0.0205 0.0205 0.0368 0.1098 0.1276 0.0598 0.1264 ⋯
# 5   0.0762 0.0666 0.0481 0.0394 0.0590 0.0649 0.1209 0.2467 0.3564 0.4459 ⋯
# 6   0.0286 0.0453 0.0277 0.0174 0.0384 0.0990 0.1201 0.1833 0.2105 0.3039 ⋯
# 7   0.0317 0.0956 0.1321 0.1408 0.1674 0.1710 0.0731 0.1401 0.2083 0.3513 ⋯
# 8   0.0519 0.0548 0.0842 0.0319 0.1158 0.0922 0.1027 0.0613 0.1465 0.2838 ⋯
# 9   0.0223 0.0375 0.0484 0.0475 0.0647 0.0591 0.0753 0.0098 0.0684 0.1487 ⋯
# 10  0.0164 0.0173 0.0347 0.0070 0.0187 0.0671 0.1056 0.0697 0.0962 0.0251 ⋯
# 11  0.0039 0.0063 0.0152 0.0336 0.0310 0.0284 0.0396 0.0272 0.0323 0.0452 ⋯
# 12  0.0123 0.0309 0.0169 0.0313 0.0358 0.0102 0.0182 0.0579 0.1122 0.0835 ⋯
# 13  0.0079 0.0086 0.0055 0.0250 0.0344 0.0546 0.0528 0.0958 0.1009 0.1240 ⋯
# 14  0.0090 0.0062 0.0253 0.0489 0.1197 0.1589 0.1392 0.0987 0.0955 0.1895 ⋯
# 15  0.0124 0.0433 0.0604 0.0449 0.0597 0.0355 0.0531 0.0343 0.1052 0.2120 ⋯
# 16  0.0298 0.0615 0.0650 0.0921 0.1615 0.2294 0.2176 0.2033 0.1459 0.0852 ⋯
# 17  0.0352 0.0116 0.0191 0.0469 0.0737 0.1185 0.1683 0.1541 0.1466 0.2912 ⋯
# 194 0.0134 0.0094 0.0047 0.0045 0.0042 0.0028 0.0036 0.0013 0.0016
# 195 0.0083 0.0080 0.0026 0.0079 0.0042 0.0071 0.0044 0.0022 0.0014
# 196 0.0124 0.0093 0.0072 0.0019 0.0027 0.0054 0.0017 0.0024 0.0029
# 197 0.0165 0.0056 0.0010 0.0027 0.0062 0.0024 0.0063 0.0017 0.0028
# 198 0.0132 0.0027 0.0022 0.0059 0.0016 0.0025 0.0017 0.0027 0.0027
# 199 0.0096 0.0071 0.0084 0.0038 0.0026 0.0028 0.0013 0.0035 0.0060
# 200 0.0141 0.0103 0.0100 0.0034 0.0026 0.0037 0.0044 0.0057 0.0035
# 201 0.0150 0.0076 0.0032 0.0037 0.0071 0.0040 0.0009 0.0015 0.0085
# 202 0.0120 0.0039 0.0053 0.0062 0.0046 0.0045 0.0022 0.0005 0.0031
# 203 0.0091 0.0045 0.0043 0.0043 0.0098 0.0054 0.0051 0.0065 0.0103
# 204 0.0116 0.0098 0.0199 0.0033 0.0101 0.0065 0.0115 0.0193 0.0157
# 205 0.0061 0.0093 0.0135 0.0063 0.0063 0.0034 0.0032 0.0062 0.0067
# 206 0.0160 0.0029 0.0051 0.0062 0.0089 0.0140 0.0138 0.0077 0.0031
# 207 0.0086 0.0046 0.0126 0.0036 0.0035 0.0034 0.0079 0.0036 0.0048
# 208 0.0146 0.0129 0.0047 0.0039 0.0061 0.0040 0.0036 0.0061 0.0115
#     classification
# 1   R
# 2   R
# 3   R
# 4   R
# 5   R
# 6   R
# 7   R
# 8   R
# 9   R
# 10  R
# 11  R
# 12  R
# 13  R
# 14  R
# 15  R
# 16  R
# 17  R
# 18  R
# 19  R
# 20  R
# 21  R
# 22  R
# 23  R
# 24  R
# 25  R
# 26  R
# 27  R
# 28  R
# 29  R
# 30  R
# ⋮   ⋮
# 179 M
# 180 M
# 181 M
# 182 M
# 183 M
# 184 M
# 185 M
# 186 M
# 187 M
# 188 M
# 189 M
# 190 M
# 191 M
# 192 M
# 193 M
# 194 M
# 195 M
# 196 M
# 197 M
# 198 M
# 199 M
# 200 M
# 201 M
# 202 M
# 203 M
# 204 M
# 205 M
# 206 M
# 207 M
# 208 M

# %%
data_split <- initial_split(data, prop = 0.75, strata = classification)
    data_training <- training(data_split) #Creates training set

quantity_tbl <- tibble(R_quantity = filter(data_training, classification == "R") %>% nrow(), M_quantity = filter(data_training, classification == "M") %>% nrow())
quantity_tbl #Shows the amount of rows per class

mean_fb_tbl_r <- data_training %>%
                filter(classification == "R") %>%
                select(FB_1:FB_60) %>%
                map_df(mean) %>%
                bind_cols(classification = "R")
#The mean value for each frequency band of class r

mean_fb_tbl_m <- data_training %>%
                filter(classification == "M") %>%
                select(FB_1:FB_60) %>%
                map_df(mean) %>% #no missing data as otherwise this would have given an error
                bind_cols(classification = "M")
#The mean value for each frequency band of class m

mean_fb_tbl <- bind_rows(mean_fb_tbl_r, mean_fb_tbl_m) 
mean_fb_tbl #Shows the mean value for each frequency band by class
# Out:
#   R_quantity M_quantity
# 1 73         84
#   FB_1       FB_2       FB_3       FB_4       FB_5       FB_6      FB_7
# 1 0.02119315 0.03196438 0.03742055 0.04398356 0.06131918 0.1007247 0.1157548
# 2 0.03439643 0.04265119 0.04600595 0.05900833 0.08557143 0.1116917 0.1273750
#   FB_8      FB_9      FB_10     ⋯ FB_52      FB_53       FB_54
# 1 0.1170589 0.1328411 0.1582068 ⋯ 0.01076027 0.009667123 0.009750685
# 2 0.1420286 0.2074131 0.2532571 ⋯ 0.01479286 0.011300000 0.011751190
#   FB_55       FB_56       FB_57       FB_58       FB_59       FB_60
# 1 0.008463014 0.008090411 0.007975342 0.006527397 0.006827397 0.006065753
# 2 0.009648810 0.008903571 0.007647619 0.009145238 0.008672619 0.006982143
#   classification
# 1 R
# 2 M

# %%
options(repr.plot.width = 6, repr.plot.height = 10)
data_tall <- gather(data_training, key = FB, value = value, FB_1:FB_60) #%>%
           # order()
data_tall

data_tall_plot <- ggplot(data_tall, (aes(x = FB, y = value))) +
            geom_bar(position = position_dodge(width = 0.7), stat = 'identity', aes(fill = classification)) +
            coord_flip() +
            labs(x = "Frequency Band", y = "Energy Value", fill = "Mine or Rock" ) +
            ggtitle("Energy Value of Each Frequency \nBand by Material") +
            theme(text = element_text(size = 15))

data_tall_plot
# Out:
#      classification FB    value
# 1    R              FB_1  0.0200
# 2    R              FB_1  0.0453
# 3    R              FB_1  0.0262
# 4    R              FB_1  0.0100
# 5    R              FB_1  0.0286
# 6    R              FB_1  0.0317
# 7    R              FB_1  0.0519
# 8    R              FB_1  0.0223
# 9    R              FB_1  0.0164
# 10   R              FB_1  0.0039
# 11   R              FB_1  0.0123
# 12   R              FB_1  0.0079
# 13   R              FB_1  0.0090
# 14   R              FB_1  0.0298
# 15   R              FB_1  0.0352
# 16   R              FB_1  0.0192
# 17   R              FB_1  0.0473
# 18   R              FB_1  0.0099
# 19   R              FB_1  0.0115
# 20   R              FB_1  0.0293
# 21   R              FB_1  0.0201
# 22   R              FB_1  0.0151
# 23   R              FB_1  0.0177
# 24   R              FB_1  0.0100
# 25   R              FB_1  0.0189
# 26   R              FB_1  0.0240
# 27   R              FB_1  0.0195
# 28   R              FB_1  0.0442
# 29   R              FB_1  0.0311
# 30   R              FB_1  0.0206
# ⋮    ⋮              ⋮     ⋮
# 9391 M              FB_60 0.0068
# 9392 M              FB_60 0.0043
# 9393 M              FB_60 0.0051
# 9394 M              FB_60 0.0036
# 9395 M              FB_60 0.0054
# 9396 M              FB_60 0.0087
# 9397 M              FB_60 0.0054
# 9398 M              FB_60 0.0017
# 9399 M              FB_60 0.0033
# 9400 M              FB_60 0.0057
# 9401 M              FB_60 0.0058
# 9402 M              FB_60 0.0042
# 9403 M              FB_60 0.0052
# 9404 M              FB_60 0.0018
# 9405 M              FB_60 0.0021
# 9406 M              FB_60 0.0007
# 9407 M              FB_60 0.0016
# 9408 M              FB_60 0.0029
# 9409 M              FB_60 0.0028
# 9410 M              FB_60 0.0027
# 9411 M              FB_60 0.0060
# 9412 M              FB_60 0.0035
# 9413 M              FB_60 0.0085
# 9414 M              FB_60 0.0031
# 9415 M              FB_60 0.0103
# 9416 M              FB_60 0.0157
# 9417 M              FB_60 0.0067
# 9418 M              FB_60 0.0031
# 9419 M              FB_60 0.0048
# 9420 M              FB_60 0.0115
# plot without title

# %% [markdown]
# #####
